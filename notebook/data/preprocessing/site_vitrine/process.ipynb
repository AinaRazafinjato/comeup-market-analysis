# %% [markdown]
# # Data Analysis of Comeup Website Services
#
# This notebook analyzes web development services data scraped from Comeup.com, a French freelance marketplace. The dataset contains information about various web development services offered by freelancers, including pricing, ratings, technologies used, and service categories.
#
# ## Dataset Overview
#
# The dataset includes **50 services** from different vendors with the following key attributes:
# - **Vendor information**: Names and service descriptions
# - **Pricing data**: Service costs in GBP
# - **Quality metrics**: Ratings and number of reviews
# - **Technical details**: Technologies and platforms used
# - **Service categorization**: Type of web development service offered
#
# ## Key Insights Preview
#
# From the initial data exploration, we can observe:
# - Services range from basic WordPress sites (£12.64) to premium custom solutions (£674.11)
# - Most services maintain high ratings (4.9-5.0 stars)
# - WordPress dominates as the primary technology platform
# - Services span multiple categories including website development, web design, and SEO optimization

# %%
# Import necessary libraries
import pandas as pd
from collections import Counter
import re

# %%
# Set data directory path and load the dataset
data_raw_dir = '../../../data/raw/'

# Load the dataset directly into a DataFrame
df = pd.read_csv(data_raw_dir + 'comeup-category-site-vitrine.csv')

# %%
# Suppression des colonnes avec des valeurs non pertinentes ou nulles
df = df.drop(columns=['colorGrey350 2', 'colorGrey350 3', 'colorGrey350 4', 'colorGrey350 5', 'colorGrey200', 'colorGrey200 2', 'affiche'])

# Info sur les colonnes supprimées
print(f"Colonnes restantes: {df.columns.tolist()}")
print(f"Shape après suppression: {df.shape}")
# Out:
# Colonnes restantes: ['d-block src', 'me-3 src', 'vendeur', 'description', 'stretched-link href', 'mb-1', 'note', 'nb-rate']
# Shape après suppression: (50, 8)

# %%
# Renommage des colonnes pour une meilleure lisibilité
df = df.rename(columns={
    'd-block src': 'Image_URL',
    'me-3 src': 'Vendor_Image_URL',
    'vendeur': 'Vendor_Name',
    'description': 'Service_Description',
    'stretched-link href': 'Service_Link',
    'mb-1': 'Price',
    'note': 'Rating',
    'nb-rate': 'Number_of_Ratings'
})

print("Colonnes renommées:")
print(df.columns.tolist())
# Out:
# Colonnes renommées:
# ['Image_URL', 'Vendor_Image_URL', 'Vendor_Name', 'Service_Description', 'Service_Link', 'Price', 'Rating', 'Number_of_Ratings']

# %%
# Vérification des valeurs manquantes avant nettoyage
print("Valeurs manquantes par colonne:")
print(df.isnull().sum())
print(f"\nNombre total de lignes: {len(df)}")
# Out:
# Valeurs manquantes par colonne:
# Image_URL              0
# Vendor_Image_URL       0
# Vendor_Name            0
# Service_Description    0
# Service_Link           0
# Price                  0
# Rating                 1
# Number_of_Ratings      1
# dtype: int64
#
# Nombre total de lignes: 50

# %%
# Suppression des lignes avec des valeurs manquantes dans les colonnes critiques
colonnes_critiques = ['Vendor_Name', 'Service_Description', 'Price', 'Rating', 'Number_of_Ratings']
df = df.dropna(subset=colonnes_critiques)

print(f"Lignes restantes après suppression: {len(df)}")
print("Valeurs manquantes après nettoyage:")
print(df.isnull().sum())
# Out:
# Lignes restantes après suppression: 49
# Valeurs manquantes après nettoyage:
# Image_URL              0
# Vendor_Image_URL       0
# Vendor_Name            0
# Service_Description    0
# Service_Link           0
# Price                  0
# Rating                 0
# Number_of_Ratings      0
# dtype: int64

# %%
# Conversion du prix en valeur numérique
print("Exemples de prix avant nettoyage:")
print(df['Price'].head(10))

df['Price'] = df['Price'].str.extract(r'(\d+[\\.,]?\d*)').replace(',', '.', regex=True).astype(float)

print("\nPrix après nettoyage:")
print(df['Price'].head(10))
print(f"Prix min: {df['Price'].min()}, Prix max: {df['Price'].max()}")
# Out:
# Exemples de prix avant nettoyage:
# 1     À partir de 328,63 £GB
# 2     À partir de 332,84 £GB
# 3      À partir de 42,13 £GB
# 4     À partir de 328,63 £GB
# 5     À partir de 589,85 £GB
# 6     À partir de 674,11 £GB
# 7     À partir de 164,31 £GB
# 8     À partir de 164,31 £GB
# 9     À partir de 417,11 £GB
# 10    À partir de 210,66 £GB
# Name: Price, dtype: object
#
# Prix après nettoyage:
# 1     328.63
# 2     332.84
# 3      42.13
# 4     328.63
# 5     589.85
# 6     674.11
# 7     164.31
# 8     164.31
# 9     417.11
# 10    210.66
# Name: Price, dtype: float64
# Prix min: 12.64, Prix max: 674.11

# %%
# Nettoyage de la colonne Rating
print("Exemples de ratings avant nettoyage:")
print(df['Rating'].head(10))

df['Rating'] = df['Rating'].str.replace(',', '.').astype(float)

print("\nRatings après nettoyage:")
print(df['Rating'].head(10))
print(f"Rating min: {df['Rating'].min()}, Rating max: {df['Rating'].max()}")
# Out:
# Exemples de ratings avant nettoyage:
# 1     5,0
# 2     5,0
# 3     5,0
# 4     5,0
# 5     5,0
# 6     4,9
# 7     5,0
# 8     5,0
# 9     5,0
# 10    5,0
# Name: Rating, dtype: object
#
# Ratings après nettoyage:
# 1     5.0
# 2     5.0
# 3     5.0
# 4     5.0
# 5     5.0
# 6     4.9
# 7     5.0
# 8     5.0
# 9     5.0
# 10    5.0
# Name: Rating, dtype: float64
# Rating min: 4.9, Rating max: 5.0

# %%
# Extraction des valeurs numériques de Number_of_Ratings
print("Exemples de number_of_ratings avant nettoyage:")
print(df['Number_of_Ratings'].head(10))

df['Number_of_Ratings'] = df['Number_of_Ratings'].str.extract(r'(\d+)').astype(int)

print("\nNumber_of_Ratings après nettoyage:")
print(df['Number_of_Ratings'].head(10))
print(f"Nombre d'évaluations min: {df['Number_of_Ratings'].min()}, max: {df['Number_of_Ratings'].max()}")
# Out:
# Exemples de number_of_ratings avant nettoyage:
# 1     (141)
# 2     (384)
# 3      (10)
# 4      (83)
# 5      (33)
# 6      (46)
# 7      (32)
# 8     (281)
# 9      (43)
# 10     (78)
# Name: Number_of_Ratings, dtype: object
#
# Number_of_Ratings après nettoyage:
# 1     141
# 2     384
# 3      10
# 4      83
# 5      33
# 6      46
# 7      32
# 8     281
# 9      43
# 10     78
# Name: Number_of_Ratings, dtype: int32
# Nombre d'évaluations min: 1, max: 384

# %%
# Reset de l'index
df = df.reset_index(drop=True)
print(f"Dataframe final shape: {df.shape}")
print("\nPremières lignes du dataframe nettoyé:")
df.head()
# Out:
# Dataframe final shape: (49, 8)
#
# Premières lignes du dataframe nettoyé:
#                                            Image_URL  \
# 0  https://thumbor.comeup.com/nANntK1xwVY8UAdLIRO...
# 1  https://thumbor.comeup.com/I6QTBL8dkCj0DS33mRl...
# 2  https://thumbor.comeup.com/aUORgiOzZB1wCeSXsTU...
# 3  https://thumbor.comeup.com/Niq9MJKl4hYZ9e0LbRx...
# 4  https://thumbor.comeup.com/NhWS2Q82LvT_EO1_1Kp...
#
#                                     Vendor_Image_URL         Vendor_Name  \
# 0  https://thumbor.comeup.com/QfSpUO0DaPYjoMIGGxh...        UpWeb_Agency
# 1  https://thumbor.comeup.com/W-_IGvlC1p2f-mPTSBy...  Caroline_WordPress
# 2  https://thumbor.comeup.com/k1c7EOqwSJshNHpmLq3...         Netcoaching
# 3  https://thumbor.comeup.com/ssg3Cav2fLmtJe3IzJT...             EcomDev
# 4  https://thumbor.comeup.com/MKqdGSoYYMaJaJhUuuQ...        hbconsultant
#
#                                  Service_Description  \
# 0  Je vais créer votre site web, vitrine WordPres...
# 1  Je vais créer votre site web WordPress personn...
# 2  Je vais créer ou faire la refonte Premium de v...
# 3  Je vais créer votre site web optimisé SEO avec...
# 4  Je vais vous aider à développer votre site des...
#
#                                         Service_Link   Price  Rating  \
# 0  https://comeup.com/fr/service/143078/creer-vot...  328.63     5.0
# 1  https://comeup.com/fr/service/141075/creer-vot...  332.84     5.0
# 2  https://comeup.com/api/stats/click/9b27b3f6907...   42.13     5.0
# 3  https://comeup.com/fr/service/270709/creer-vot...  328.63     5.0
# 4  https://comeup.com/fr/service/55271/vous-aider...  589.85     5.0
#
#    Number_of_Ratings
# 0                141
# 1                384
# 2                 10
# 3                 83
# 4                 33

# %%
# Fonction de catégorisation des services
def categorize_service(description):
    if "WordPress" in description:
        return "Website Development"
    elif "SEO" in description:
        return "SEO Optimization"
    elif "Elementor" in description or "Divi" in description:
        return "Web Design"
    else:
        return "Other"

# Application de la catégorisation
df['Category'] = df['Service_Description'].apply(categorize_service)

print("Distribution des catégories:")
print(df['Category'].value_counts())
# Out:
# Distribution des catégories:
# Category
# Website Development    21
# Other                  21
# Web Design              5
# SEO Optimization        2
# Name: count, dtype: int64

# %%
# Sélection des colonnes à conserver pour l'étude de marché
columns_to_keep = ["Vendor_Name", "Service_Description", "Price", "Rating", "Number_of_Ratings", "Category"]
df = df[columns_to_keep]

print(f"Colonnes finales: {df.columns.tolist()}")
print(f"Shape final avant analyse technologique: {df.shape}")
# Out:
# Colonnes finales: ['Vendor_Name', 'Service_Description', 'Price', 'Rating', 'Number_of_Ratings', 'Category']
# Shape final avant analyse technologique: (49, 6)

# %%
# Dictionnaire des technologies avec leurs variantes
tech_patterns = {
    'WordPress': r'\b(wordpress|wp)\b',
    'Webflow': r'\b(webflow)\b',
    'Divi': r'\b(divi)\b', 
    'Elementor': r'\b(elementor)\b',
    'Wix': r'\b(wix)\b',
    'Drupal': r'\b(drupal)\b',
    'NextJs': r'\b(nextjs|next\.js|next js)\b',
    'Framer': r'\b(framer)\b',
    'Django': r'\b(django)\b',
    'Woocommerce': r'\b(woocommerce|woo commerce)\b',
    'HTML': r'\b(html|html5)\b',
    'CSS': r'\b(css|css3)\b',
    'JavaScript': r'\b(javascript|js)\b',
    'PHP': r'\b(php)\b',
    'React': r'\b(react|reactjs)\b',
    'Vue': r'\b(vue|vuejs)\b'
}

print(f"Technologies à détecter: {list(tech_patterns.keys())}")
# Out:
# Technologies à détecter: ['WordPress', 'Webflow', 'Divi', 'Elementor', 'Wix', 'Drupal', 'NextJs', 'Framer', 'Django', 'Woocommerce', 'HTML', 'CSS', 'JavaScript', 'PHP', 'React', 'Vue']

# %%
def categorize_techno_improved(description):
    """Retourne toutes les technologies trouvées dans la description"""
    if pd.isna(description):
        return ['Unprecised']
    
    # Gestion du cas spécial "pas de WordPress"
    if re.search(r'\b(pas de wordpress|sans wordpress|no wordpress)\b', description, re.IGNORECASE):
        return ['Pas de WordPress']
    
    found_techs = []
    description_lower = description.lower()
    
    for tech, pattern in tech_patterns.items():
        if re.search(pattern, description_lower, re.IGNORECASE):
            found_techs.append(tech)
    
    return found_techs if found_techs else ['Unprecised']

print("Fonction de catégorisation technologique définie")
# Out:
# Fonction de catégorisation technologique définie

# %%
# Application de la catégorisation technologique
df['Techno_List'] = df['Service_Description'].apply(categorize_techno_improved)

print("Exemples de technologies détectées:")
for i in range(min(5, len(df))):
    print(f"Service {i+1}: {df.iloc[i]['Techno_List']}")
# Out:
# Exemples de technologies détectées:
# Service 1: ['WordPress', 'Divi']
# Service 2: ['WordPress', 'Divi', 'Elementor']
# Service 3: ['Divi', 'Elementor']
# Service 4: ['WordPress']
# Service 5: ['Unprecised']

# %%
# Création des colonnes d'analyse technologique
df['Techno_Main'] = df['Techno_List'].apply(
    lambda x: x[0] if len(x) == 1 else 'Multiple' if len(x) > 1 else 'Unprecised'
)

df['Techno_Count'] = df['Techno_List'].apply(len)
df['Is_Multi_Tech'] = df['Techno_Count'] > 1

print(f"Services avec une seule technologie: {sum(df['Techno_Count'] == 1)}")
print(f"Services multi-technologies: {sum(df['Is_Multi_Tech'])}")
print(f"Services sans technologie précisée: {sum(df['Techno_List'].apply(lambda x: x == ['Unprecised']))}")
# Out:
# Services avec une seule technologie: 38
# Services multi-technologies: 11
# Services sans technologie précisée: 10

# %%
# Statistiques des technologies
all_technologies = [tech for tech_list in df['Techno_List'] for tech in tech_list]
tech_counts = Counter(all_technologies)

print("Technologies les plus utilisées:")
for tech, count in tech_counts.most_common():
    print(f"{tech}: {count}")
# Out:
# Technologies les plus utilisées:
# WordPress: 28
# Unprecised: 10
# Divi: 8
# Elementor: 6
# Wix: 2
# NextJs: 2
# HTML: 1
# CSS: 1
# JavaScript: 1
# PHP: 1
# Pas de WordPress: 1
# Webflow: 1
# Drupal: 1
# Framer: 1
# Django: 1
# Woocommerce: 1

# %%
# Services multi-technologies
multi_tech_services = df[df['Is_Multi_Tech']]
print(f"Nombre de services multi-tech: {len(multi_tech_services)}")

# Combinaisons fréquentes
if len(multi_tech_services) > 0:
    combinations = df[df['Is_Multi_Tech']]['Techno_List'].apply(
        lambda x: ', '.join(sorted(x))
    ).value_counts()
    
    print("\nCombinaisons les plus fréquentes:")
    print(combinations.head())
else:
    print("Aucune combinaison de technologies trouvée")
# Out:
# Nombre de services multi-tech: 11
#
# Combinaisons les plus fréquentes:
# Techno_List
# Divi, Elementor, WordPress    3
# Divi, WordPress               2
# Divi, Elementor               2
# CSS, HTML, JavaScript, PHP    1
# Drupal, Wix, WordPress        1
# Name: count, dtype: int64

# %%
# Aperçu final du dataframe
print("Colonnes finales:")
print(df.columns.tolist())
print(f"\nShape final: {df.shape}")
print("\nPremières lignes:")

df
# Out:
# Colonnes finales:
# ['Vendor_Name', 'Service_Description', 'Price', 'Rating', 'Number_of_Ratings', 'Category', 'Techno_List', 'Techno_Main', 'Techno_Count', 'Is_Multi_Tech']
#
# Shape final: (49, 10)
#
# Premières lignes:
#            Vendor_Name                                Service_Description  \
# 0         UpWeb_Agency  Je vais créer votre site web, vitrine WordPres...
# 1   Caroline_WordPress  Je vais créer votre site web WordPress personn...
# 2          Netcoaching  Je vais créer ou faire la refonte Premium de v...
# 3              EcomDev  Je vais créer votre site web optimisé SEO avec...
# 4         hbconsultant  Je vais vous aider à développer votre site des...
# 5           gataka_web  Je vais créer un site internet professionnel a...
# 6           Franki1607  Je vais coder votre site professionnel avec ht...
# 7          SolutionWeb  Je vais créer votre site web sur mesure optimi...
# 8        ConsultantWeb            Je vais créer un site web professionnel
# 9          horizonplus  Je vais créer votre site web ou refondre votre...
# 10          Youcef_web  Je vais créer votre site WordPress (vitrine, o...
# 11               WebCH  Je vais réaliser votre vitrine web (pas de Wor...
# 12               Sitee            Je vais créer votre site web sur mesure
# 13           Martin_JS         Je vais faire la refonte de site WordPress
# 14    WebflowFreelance  Je vais créer votre site vitrine professionnel...
# 15      Webdesignerpro  Je vais créer un site internet professionnel c...
# 16               IvanR  Je vais créer votre site web sur mesure avec W...
# 17            EmericKA  Je vais créer votre site vitrine / blog / e-co...
# 18           kategriss    Je vais créer un site web clé en main avec Divi
# 19          Franki1607  Je vais créer votre site web wordpress profess...
# 20             EcomDev  Je vais créer votre site web optimisé SEO avec...
# 21            meta_web  Je vais réaliser votre site vitrine / site web...
# 22              kadama      Je vais faire la création d'un site Wordpress
# 23        ThomasHamard  Je vais développer votre SaaS avec NextJS, Sup...
# 24           Caramande  Je vais créer votre site internet commerçant o...
# 25                Yuuc         Je vais créer un site WordPress sur mesure
# 26             _maxdev           Je vais créer votre site web avec NextJS
# 27           Caramande  Je vais réaliser votre site professionnel Word...
# 28    DJones_Marketpro  Je vais faire la création optimisé SEO de votr...
# 29         PRESTA_PLUX  Je vais créer votre site web WordPress optimis...
# 30           ThibaudSa  Je vais créer votre site Internet WordPress pr...
# 31         DIVI_EXPERT  Je vais créer votre site internet Wordpress av...
# 32              WebLab     Je vais créer votre site web WordPress premium
# 33      Donatien_wpweb   Je vais créer votre site internet sous WordPress
# 34           Abdesslam  Je vais créer un Site Moderne pour Vos Réserva...
# 35     MouradLondon_WP  Je vais créer votre site internet Wordpress av...
# 36       Maryam_Design  Je vais créer un site internet professionnel a...
# 37             Lenaic_            Je vais créer votre site web sur mesure
# 38            Yohann_V  Je vais créer un site web personnalisé et mode...
# 39             Hwakrim  Je vais créer votre site web wordpress profess...
# 40         Netcoaching  Je vais créer ou faire la refonte Premium de v...
# 41              Habeuk  Je vais transformer votre maquette en un site ...
# 42            Mylene_G   Je vais créer votre site Wordpress professionnel
# 43             winnery    Je vais développer un élément de votre site web
# 44             ngadi48  Je vais creer votre site web personnalisé en p...
# 45        VilascoGomez         Je vais faire la refonte de site wordpress
# 46     Coding_Industry      Je vais développer votre site web clé en main
# 47    Clara_Consulting  Je vais vous créer un site Wordpress / Woocomm...
# 48        GraphiqueONE  Je vais créer votre site Internet WordPress de...
#
#      Price  Rating  Number_of_Ratings             Category  \
# 0   328.63     5.0                141  Website Development
# 1   332.84     5.0                384  Website Development
# 2    42.13     5.0                 10           Web Design
# 3   328.63     5.0                 83  Website Development
# 4   589.85     5.0                 33                Other
# 5   674.11     4.9                 46  Website Development
# 6   164.31     5.0                 32                Other
# 7   164.31     5.0                281  Website Development
# 8   417.11     5.0                 43                Other
# 9   210.66     5.0                 78  Website Development
# 10   12.64     5.0                276  Website Development
# 11  151.68     5.0                 53  Website Development
# 12   84.26     5.0                 69                Other
# 13  164.31     5.0                 64  Website Development
# 14  286.50     5.0                 75                Other
# 15  417.08     5.0                167                Other
# 16  101.12     5.0                 43  Website Development
# 17  252.78     5.0                 79  Website Development
# 18  248.58     4.9                 90           Web Design
# 19  160.10     5.0                 18     SEO Optimization
# 20  328.63     5.0                104     SEO Optimization
# 21   84.26     5.0                118  Website Development
# 22  126.39     5.0                 22                Other
# 23  501.34     5.0                  3                Other
# 24  484.49     5.0                 26                Other
# 25  168.52     5.0                 58  Website Development
# 26   84.26     5.0                  3                Other
# 27   21.06     5.0                 57  Website Development
# 28  210.66     5.0                 23  Website Development
# 29  311.78     5.0                  5  Website Development
# 30  210.65     5.0                 59  Website Development
# 31  581.39     5.0                297           Web Design
# 32  303.35     5.0                 13  Website Development
# 33  126.39     5.0                 28  Website Development
# 34  235.93     5.0                  1                Other
# 35  417.08     5.0                 30           Web Design
# 36  631.94     5.0                 70  Website Development
# 37  210.66     5.0                 51                Other
# 38  556.14     5.0                  1                Other
# 39  244.35     5.0                138                Other
# 40   42.13     5.0                 10           Web Design
# 41  223.30     5.0                  1                Other
# 42  151.67     5.0                  7                Other
# 43   25.28     5.0                243                Other
# 44   25.28     5.0                  4                Other
# 45   50.56     5.0                105                Other
# 46  210.66     5.0                 28                Other
# 47   12.64     5.0                  3                Other
# 48  252.78     5.0                  4  Website Development
#
#                      Techno_List       Techno_Main  Techno_Count  \
# 0              [WordPress, Divi]          Multiple             2
# 1   [WordPress, Divi, Elementor]          Multiple             3
# 2              [Divi, Elementor]          Multiple             2
# 3                    [WordPress]         WordPress             1
# 4                   [Unprecised]        Unprecised             1
# 5                    [WordPress]         WordPress             1
# 6   [HTML, CSS, JavaScript, PHP]          Multiple             4
# 7                    [WordPress]         WordPress             1
# 8                   [Unprecised]        Unprecised             1
# 9                    [WordPress]         WordPress             1
# 10                   [WordPress]         WordPress             1
# 11            [Pas de WordPress]  Pas de WordPress             1
# 12                  [Unprecised]        Unprecised             1
# 13                   [WordPress]         WordPress             1
# 14                     [Webflow]           Webflow             1
# 15                  [Unprecised]        Unprecised             1
# 16      [WordPress, Wix, Drupal]          Multiple             3
# 17                   [WordPress]         WordPress             1
# 18                        [Divi]              Divi             1
# 19                   [WordPress]         WordPress             1
# 20                         [Wix]               Wix             1
# 21                   [WordPress]         WordPress             1
# 22                   [WordPress]         WordPress             1
# 23                      [NextJs]            NextJs             1
# 24                  [Unprecised]        Unprecised             1
# 25                   [WordPress]         WordPress             1
# 26                      [NextJs]            NextJs             1
# 27                   [WordPress]         WordPress             1
# 28                   [WordPress]         WordPress             1
# 29                   [WordPress]         WordPress             1
# 30             [WordPress, Divi]          Multiple             2
# 31  [WordPress, Divi, Elementor]          Multiple             3
# 32                   [WordPress]         WordPress             1
# 33                   [WordPress]         WordPress             1
# 34                  [Unprecised]        Unprecised             1
# 35        [WordPress, Elementor]          Multiple             2
# 36                   [WordPress]         WordPress             1
# 37                  [Unprecised]        Unprecised             1
# 38                      [Framer]            Framer             1
# 39                   [WordPress]         WordPress             1
# 40             [Divi, Elementor]          Multiple             2
# 41                  [Unprecised]        Unprecised             1
# 42                   [WordPress]         WordPress             1
# 43                  [Unprecised]        Unprecised             1
# 44                      [Django]            Django             1
# 45                   [WordPress]         WordPress             1
# 46                  [Unprecised]        Unprecised             1
# 47      [WordPress, Woocommerce]          Multiple             2
# 48  [WordPress, Divi, Elementor]          Multiple             3
#
#     Is_Multi_Tech
# 0            True
# 1            True
# 2            True
# 3           False
# 4           False
# 5           False
# 6            True
# 7           False
# 8           False
# 9           False
# 10          False
# 11          False
# 12          False
# 13          False
# 14          False
# 15          False
# 16           True
# 17          False
# 18          False
# 19          False
# 20          False
# 21          False
# 22          False
# 23          False
# 24          False
# 25          False
# 26          False
# 27          False
# 28          False
# 29          False
# 30           True
# 31           True
# 32          False
# 33          False
# 34          False
# 35           True
# 36          False
# 37          False
# 38          False
# 39          False
# 40           True
# 41          False
# 42          False
# 43          False
# 44          False
# 45          False
# 46          False
# 47           True
# 48           True

# %%
data_processed_dir = "../../../data/processed/"

# Enregistrement du DataFrame nettoyé et enrichi
df.to_csv(data_processed_dir + 'comeup-category-site-vitrine-cleaned.csv', index=False)
print(f"DataFrame enregistré dans {data_processed_dir + 'comeup-category-site-vitrine-cleaned.csv'}")
# Out:
# DataFrame enregistré dans ../../../data/processed/comeup-category-site-vitrine-cleaned.csv
